# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('chicago_crime_dataset_v2.csv')
# data = data[data.Year=='2021']

# %%
data_2021 = data[data.Year==2021]

# %% [markdown]
# 1. Crime amount trend monthly
# 2. Crime type amount, also FBI Code
# 3. Crime blocks amount
# 4. blocks & types
# 5. Arrest 严重程度
# 6. Domestic 人口
# 7. Beat, District, Community Area are a type of area

# %%
data_2021.head()
# Out:
#              ID Case Number                    Date  \
# 265    12571973    JE482457  12/19/2021 07:23:00 AM
# 59361  12343475    JE202728  04/16/2021 08:45:00 PM
# 63538  12602803    JF125633  10/21/2021 11:00:00 AM
# 69374  12540388    JE444591  11/14/2021 06:00:00 AM
# 69765  12541139    JE445494  11/14/2021 04:00:00 AM
#
#                            Block  IUCR   Primary Type  \
# 265            042XX S MOZART ST  0460        BATTERY
# 59361          056XX N RIDGE AVE  0820          THEFT
# 63538   083XX S STONY ISLAND AVE  500E  OTHER OFFENSE
# 69374  086XX S COTTAGE GROVE AVE  0850          THEFT
# 69765            034XX W 38TH ST  0486        BATTERY
#
#                    Description Location Description  Arrest  Domestic  Beat  \
# 265                     SIMPLE             SIDEWALK    True      True   921
# 59361           $500 AND UNDER      OTHER (SPECIFY)   False     False  2013
# 63538            EAVESDROPPING      OTHER (SPECIFY)   False     False   412
# 69374            ATTEMPT THEFT    CONVENIENCE STORE   False     False   632
# 69765  DOMESTIC BATTERY SIMPLE            RESIDENCE   False      True   911
#
#        District  Ward  Community Area FBI Code  X Coordinate  Y Coordinate  \
# 265         9.0  15.0            58.0      08B     1158067.0     1876425.0
# 59361      20.0  48.0            77.0       06           NaN           NaN
# 63538       4.0   8.0            45.0       26     1188260.0     1849805.0
# 69374       6.0   6.0            44.0       06     1183071.0     1847869.0
# 69765       9.0  12.0            58.0      08B     1154073.0     1879187.0
#
#        Year              Updated On   Latitude  Longitude  \
# 265    2021  09/12/2022 04:45:45 PM  41.816657 -87.695689
# 59361  2021  04/23/2021 04:51:47 PM        NaN        NaN
# 63538  2021  02/27/2022 03:46:31 PM  41.742941 -87.585783
# 69374  2021  11/21/2021 03:48:03 PM  41.737751 -87.604856
# 69765  2021  11/21/2021 03:48:03 PM  41.824317 -87.710266
#
#                             Location  Historical Wards 2003-2015  Zip Codes  \
# 265     (41.81665685, -87.695688608)                        49.0    22248.0
# 59361                            NaN                         NaN        NaN
# 63538   (41.74294124, -87.585783412)                         9.0    21202.0
# 69374  (41.737750767, -87.604855911)                        31.0    21546.0
# 69765  (41.824316537, -87.710266215)                        29.0    22248.0
#
#        Community Areas  Census Tracts  Wards  Boundaries - ZIP Codes  \
# 265               55.0          156.0    3.0                    56.0
# 59361              NaN            NaN    NaN                     NaN
# 63538             41.0          133.0   35.0                    61.0
# 69374             40.0          140.0   32.0                    61.0
# 69765             55.0          612.0    1.0                    56.0
#
#        Police Districts  Police Beats
# 265                23.0         110.0
# 59361               NaN           NaN
# 63538              19.0         240.0
# 69374              20.0         241.0
# 69765              23.0          96.0

# %%
data_2021.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 208001 entries, 265 to 7691198
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ID                          208001 non-null  int64
#  1   Case Number                 208001 non-null  object
#  2   Date                        208001 non-null  object
#  3   Block                       208001 non-null  object
#  4   IUCR                        208001 non-null  object
#  5   Primary Type                208001 non-null  object
#  6   Description                 208001 non-null  object
#  7   Location Description        207150 non-null  object
#  8   Arrest                      208001 non-null  bool
#  9   Domestic                    208001 non-null  bool
#  10  Beat                        208001 non-null  int64
#  11  District                    208001 non-null  float64
#  12  Ward                        207990 non-null  float64
#  13  Community Area              208001 non-null  float64
#  14  FBI Code                    208001 non-null  object
#  15  X Coordinate                202890 non-null  float64
#  16  Y Coordinate                202890 non-null  float64
#  17  Year                        208001 non-null  int64
#  18  Updated On                  208001 non-null  object
#  19  Latitude                    202890 non-null  float64
#  20  Longitude                   202890 non-null  float64
#  21  Location                    202890 non-null  object
#  22  Historical Wards 2003-2015  202213 non-null  float64
#  23  Zip Codes                   202890 non-null  float64
#  24  Community Areas             202301 non-null  float64
#  25  Census Tracts               202327 non-null  float64
#  26  Wards                       202302 non-null  float64
#  27  Boundaries - ZIP Codes      202301 non-null  float64
#  28  Police Districts            202330 non-null  float64
#  29  Police Beats                202330 non-null  float64
# dtypes: bool(2), float64(15), int64(3), object(10)
# memory usage: 46.4+ MB

# %%
len(data_2021['FBI Code'].value_counts())
# Out:
# 26

# %%
data_2021['FBI Code'].value_counts()
# Out:
# FBI Code
# 06     40764
# 08B    32619
# 14     25091
# 08A    17132
# 11     16000
# 26     13992
# 07     10595
# 15      9148
# 04B     8347
# 03      7920
# 04A     7242
# 05      6658
# 18      5015
# 02      1675
# 17      1513
# 10      1005
# 24       902
# 01A      803
# 20       704
# 09       527
# 22       184
# 16        95
# 12        26
# 13        25
# 19        13
# 01B        6
# Name: count, dtype: int64

# %% [markdown]
# categorical:
#     when: month, day, hour
#     where: street, Beat, district
#     what: crime type, fbi code(need to check reference website)
#     who: domestic or not
# quantative:
#     crime amount
#     arrest amount
